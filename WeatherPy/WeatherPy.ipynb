# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units=imperial"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | hammerfest
# Processing Record 3 of Set 1 | talnakh
# Processing Record 4 of Set 1 | siwa oasis
# Processing Record 5 of Set 1 | kayangel
# Processing Record 6 of Set 1 | sarmiento
# Processing Record 7 of Set 1 | revda
# Processing Record 8 of Set 1 | magadan
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | lata
# Processing Record 11 of Set 1 | crane
# Processing Record 12 of Set 1 | sinaloa de leyva
# Processing Record 13 of Set 1 | margaret river
# Processing Record 14 of Set 1 | paka
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | san borja
# Processing Record 17 of Set 1 | vadso
# Processing Record 18 of Set 1 | puerto penasco
# Processing Record 19 of Set 1 | college
# Processing Record 20 of Set 1 | afaahiti
# Processing Record 21 of Set 1 | smithers
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | st. john's
# Processing Record 24 of Set 1 | callao
# Processing Record 25 of Set 1 | newman
# Processing Record 26 of Set 1 | armacao de buzios
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | polyarnyy
# Processing Record 29 of Set 1 | nabire
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | askoy
# Processing Record 32 of Set 1 | adamstown
# Processing Record 33 of Set 1 | nadym
# Processing Record 34 of Set 1 | kununurra
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | ludza
# Processing Record 37 of Set 1 | gladstone
# Processing Record 38 of Set 1 | hawaiian paradise park
# Processing Record 39 of Set 1 | blackmans bay
# Processing Record 40 of Set 1 | olonkinbyen
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | puerto natales
# Processing Record 43 of Set 1 | lydenburg
# Processing Record 44 of Set 1 | tobi village
# City not found. Skipping...
# Processing Record 45 of Set 1 | huautla de jimenez
# Processing Record 46 of Set 1 | birao
# Processing Record 47 of Set 1 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 48 of Set 1 | port blair
# Processing Record 49 of Set 1 | el granada
# Processing Record 50 of Set 1 | aguacatan
# Processing Record 0 of Set 2 | harper
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | cavalaire-sur-mer
# Processing Record 4 of Set 2 | candelaria
# Processing Record 5 of Set 2 | broken hill
# Processing Record 6 of Set 2 | la ronge
# Processing Record 7 of Set 2 | wailua homesteads
# Processing Record 8 of Set 2 | santa luzia
# Processing Record 9 of Set 2 | moree
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | whitehorse
# Processing Record 12 of Set 2 | dalandzadgad
# Processing Record 13 of Set 2 | reggane
# Processing Record 14 of Set 2 | nouadhibou
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | ancud
# Processing Record 17 of Set 2 | kupang
# Processing Record 18 of Set 2 | mejit
# Processing Record 19 of Set 2 | walvis bay
# Processing Record 20 of Set 2 | hillarys
# Processing Record 21 of Set 2 | westport
# Processing Record 22 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | oxapampa
# Processing Record 25 of Set 2 | lovisa
# Processing Record 26 of Set 2 | puerto yuca
# Processing Record 27 of Set 2 | ushuaia
# Processing Record 28 of Set 2 | tolanaro
# Processing Record 29 of Set 2 | haiku-pauwela
# Processing Record 30 of Set 2 | planadas
# Processing Record 31 of Set 2 | atafu village
# Processing Record 32 of Set 2 | mana
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | knyaze-volkonskoye
# Processing Record 35 of Set 2 | edinburgh of the seven seas
# Processing Record 36 of Set 2 | flying fish cove
# Processing Record 37 of Set 2 | vernon
# Processing Record 38 of Set 2 | west island
# Processing Record 39 of Set 2 | inirida
# Processing Record 40 of Set 2 | kosikha
# Processing Record 41 of Set 2 | mokhsogollokh
# Processing Record 42 of Set 2 | daru
# Processing Record 43 of Set 2 | toga village
# City not found. Skipping...
# Processing Record 44 of Set 2 | sishilichengzi
# City not found. Skipping...
# Processing Record 45 of Set 2 | hithadhoo
# Processing Record 46 of Set 2 | dapa
# Processing Record 47 of Set 2 | port lincoln
# Processing Record 48 of Set 2 | shofirkon shahri
# City not found. Skipping...
# Processing Record 49 of Set 2 | mubende
# Processing Record 0 of Set 3 | halifax
# Processing Record 1 of Set 3 | machali
# Processing Record 2 of Set 3 | grytviken
# Processing Record 3 of Set 3 | turbat
# Processing Record 4 of Set 3 | ashland
# Processing Record 5 of Set 3 | neiafu
# Processing Record 6 of Set 3 | wewak
# Processing Record 7 of Set 3 | mgandu
# Processing Record 8 of Set 3 | muang phon-hong
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | es castell
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | happy valley-goose bay
# Processing Record 13 of Set 3 | al jawf
# Processing Record 14 of Set 3 | moyale
# Processing Record 15 of Set 3 | enewetak
# Processing Record 16 of Set 3 | fale old settlement
# Processing Record 17 of Set 3 | porto novo
# Processing Record 18 of Set 3 | vila franca do campo
# Processing Record 19 of Set 3 | kolwezi
# Processing Record 20 of Set 3 | tromso
# Processing Record 21 of Set 3 | zaraza
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | sao joao da barra
# Processing Record 24 of Set 3 | taoudenni
# Processing Record 25 of Set 3 | rongelap
# Processing Record 26 of Set 3 | beyneu
# Processing Record 27 of Set 3 | antalaha
# Processing Record 28 of Set 3 | shimoda
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | cannonvale
# Processing Record 31 of Set 3 | gazojak
# Processing Record 32 of Set 3 | margate
# Processing Record 33 of Set 3 | talara
# Processing Record 34 of Set 3 | erdenet
# Processing Record 35 of Set 3 | sisimiut
# Processing Record 36 of Set 3 | mahina
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | sungai penuh
# Processing Record 39 of Set 3 | constantia
# Processing Record 40 of Set 3 | birjand
# Processing Record 41 of Set 3 | laoang
# Processing Record 42 of Set 3 | kiunga
# Processing Record 43 of Set 3 | salida
# Processing Record 44 of Set 3 | labrador city
# Processing Record 45 of Set 3 | salahonda
# Processing Record 46 of Set 3 | harstad
# Processing Record 47 of Set 3 | port saint john's
# Processing Record 48 of Set 3 | taro
# Processing Record 49 of Set 3 | mount pearl
# Processing Record 0 of Set 4 | saldanha
# Processing Record 1 of Set 4 | dryden
# Processing Record 2 of Set 4 | hermanus
# Processing Record 3 of Set 4 | vorgashor
# Processing Record 4 of Set 4 | darwin
# Processing Record 5 of Set 4 | lyskovo
# Processing Record 6 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 7 of Set 4 | madalena
# Processing Record 8 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 4 | notodden
# Processing Record 10 of Set 4 | bikenibeu village
# Processing Record 11 of Set 4 | cestos city
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | trunovskoye
# Processing Record 14 of Set 4 | pangody
# Processing Record 15 of Set 4 | jamestown
# Processing Record 16 of Set 4 | taroa
# Processing Record 17 of Set 4 | papatowai
# Processing Record 18 of Set 4 | miramichi
# Processing Record 19 of Set 4 | kapuskasing
# Processing Record 20 of Set 4 | port douglas
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | san patricio
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | badger
# Processing Record 25 of Set 4 | nadi
# Processing Record 26 of Set 4 | xai-xai
# Processing Record 27 of Set 4 | ketchikan
# Processing Record 28 of Set 4 | cloquet
# Processing Record 29 of Set 4 | uliastay
# Processing Record 30 of Set 4 | bontang
# Processing Record 31 of Set 4 | mangrol
# Processing Record 32 of Set 4 | lagoa
# Processing Record 33 of Set 4 | tura
# Processing Record 34 of Set 4 | invercargill
# Processing Record 35 of Set 4 | palikir - national government center
# Processing Record 36 of Set 4 | jilib
# Processing Record 37 of Set 4 | laojunmiao
# Processing Record 38 of Set 4 | egilsstadir
# Processing Record 39 of Set 4 | isafjordur
# Processing Record 40 of Set 4 | hadibu
# Processing Record 41 of Set 4 | bilibino
# Processing Record 42 of Set 4 | manistee
# Processing Record 43 of Set 4 | kirakira
# Processing Record 44 of Set 4 | san jose village
# City not found. Skipping...
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | conceicao do rio verde
# Processing Record 47 of Set 4 | yevpatoriya
# Processing Record 48 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 49 of Set 4 | hualien city
# Processing Record 0 of Set 5 | jiazi
# Processing Record 1 of Set 5 | vrangel'
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | cabo san lucas
# Processing Record 4 of Set 5 | murang'a
# Processing Record 5 of Set 5 | galveston
# Processing Record 6 of Set 5 | nar'yan-mar
# Processing Record 7 of Set 5 | tazovsky
# Processing Record 8 of Set 5 | anadyr
# Processing Record 9 of Set 5 | itaituba
# Processing Record 10 of Set 5 | tevragh zeina
# City not found. Skipping...
# Processing Record 11 of Set 5 | koidu
# Processing Record 12 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 13 of Set 5 | carauari
# Processing Record 14 of Set 5 | ulsteinvik
# Processing Record 15 of Set 5 | christchurch
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | dzilam gonzalez
# Processing Record 18 of Set 5 | yulinshi
# Processing Record 19 of Set 5 | manta
# Processing Record 20 of Set 5 | pandan
# Processing Record 21 of Set 5 | khurba
# Processing Record 22 of Set 5 | acarau
# Processing Record 23 of Set 5 | ola
# Processing Record 24 of Set 5 | katsuren-haebaru
# Processing Record 25 of Set 5 | lagunas
# Processing Record 26 of Set 5 | batang
# Processing Record 27 of Set 5 | saipan
# Processing Record 28 of Set 5 | muscat
# Processing Record 29 of Set 5 | fort bragg
# Processing Record 30 of Set 5 | new norfolk
# Processing Record 31 of Set 5 | kodiak
# Processing Record 32 of Set 5 | las palmas de gran canaria
# Processing Record 33 of Set 5 | marine corps base hawaii - mcbh
# Processing Record 34 of Set 5 | colac
# Processing Record 35 of Set 5 | yigo village
# Processing Record 36 of Set 5 | santa teresa
# Processing Record 37 of Set 5 | suva
# Processing Record 38 of Set 5 | meadow lake
# Processing Record 39 of Set 5 | port alfred
# Processing Record 40 of Set 5 | rio grande
# Processing Record 41 of Set 5 | lepsy
# Processing Record 42 of Set 5 | punta arenas
# Processing Record 43 of Set 5 | iskateley
# Processing Record 44 of Set 5 | hasaki
# Processing Record 45 of Set 5 | sakakah
# Processing Record 46 of Set 5 | pacific grove
# Processing Record 47 of Set 5 | shadrinsk
# Processing Record 48 of Set 5 | saint-philippe
# Processing Record 49 of Set 5 | alofi
# Processing Record 0 of Set 6 | dodge city
# Processing Record 1 of Set 6 | hazorasp
# Processing Record 2 of Set 6 | chui
# Processing Record 3 of Set 6 | selfoss
# Processing Record 4 of Set 6 | juan griego
# Processing Record 5 of Set 6 | greenville
# Processing Record 6 of Set 6 | la libertad
# Processing Record 7 of Set 6 | lebu
# Processing Record 8 of Set 6 | perm
# Processing Record 9 of Set 6 | nova sintra
# Processing Record 10 of Set 6 | norman gardens
# Processing Record 11 of Set 6 | ormara
# Processing Record 12 of Set 6 | kapa'a
# Processing Record 13 of Set 6 | ko pha ngan
# Processing Record 14 of Set 6 | tralee
# Processing Record 15 of Set 6 | platnirovskaya
# Processing Record 16 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 6 | pultusk
# Processing Record 18 of Set 6 | barcelos
# Processing Record 19 of Set 6 | aasiaat
# Processing Record 20 of Set 6 | tazacorte
# Processing Record 21 of Set 6 | nuuk
# Processing Record 22 of Set 6 | taybad
# Processing Record 23 of Set 6 | kristiansund
# Processing Record 24 of Set 6 | yaren
# Processing Record 25 of Set 6 | cambria
# Processing Record 26 of Set 6 | holualoa
# Processing Record 27 of Set 6 | shahr-e babak
# Processing Record 28 of Set 6 | wayne
# Processing Record 29 of Set 6 | alness
# Processing Record 30 of Set 6 | batouri
# Processing Record 31 of Set 6 | pekan
# Processing Record 32 of Set 6 | kerema
# Processing Record 33 of Set 6 | mount gambier
# Processing Record 34 of Set 6 | stanley
# Processing Record 35 of Set 6 | rayong
# Processing Record 36 of Set 6 | itupiranga
# Processing Record 37 of Set 6 | cahri
# City not found. Skipping...
# Processing Record 38 of Set 6 | am djarass
# City not found. Skipping...
# Processing Record 39 of Set 6 | kuanda
# Processing Record 40 of Set 6 | tabuk
# Processing Record 41 of Set 6 | qaqortoq
# Processing Record 42 of Set 6 | minas de marcona
# Processing Record 43 of Set 6 | sattahip
# Processing Record 44 of Set 6 | salalah
# Processing Record 45 of Set 6 | yoloten
# Processing Record 46 of Set 6 | livingston
# Processing Record 47 of Set 6 | nizhneudinsk
# Processing Record 48 of Set 6 | chonchi
# Processing Record 49 of Set 6 | khovd
# Processing Record 0 of Set 7 | mahibadhoo
# Processing Record 1 of Set 7 | ungsang-nodongjagu
# Processing Record 2 of Set 7 | kourou
# Processing Record 3 of Set 7 | udachny
# Processing Record 4 of Set 7 | warrnambool
# Processing Record 5 of Set 7 | dumfries
# Processing Record 6 of Set 7 | conceicao da barra
# Processing Record 7 of Set 7 | sinabang
# Processing Record 8 of Set 7 | inhambane
# Processing Record 9 of Set 7 | valdivia
# Processing Record 10 of Set 7 | remire-montjoly
# Processing Record 11 of Set 7 | tsiombe
# Processing Record 12 of Set 7 | n'zeto
# Processing Record 13 of Set 7 | ta`u
# Processing Record 14 of Set 7 | uturoa
# Processing Record 15 of Set 7 | qarauyl
# Processing Record 16 of Set 7 | ust-nera
# Processing Record 17 of Set 7 | khamis mushait
# Processing Record 18 of Set 7 | fort mcmurray
# Processing Record 19 of Set 7 | tchibanga
# Processing Record 20 of Set 7 | pasni
# Processing Record 21 of Set 7 | lethem
# Processing Record 22 of Set 7 | quellon
# Processing Record 23 of Set 7 | lihue
# Processing Record 24 of Set 7 | mazamari
# Processing Record 25 of Set 7 | sogndal
# Processing Record 26 of Set 7 | mazagao
# Processing Record 27 of Set 7 | semey
# Processing Record 28 of Set 7 | bambanglipuro
# Processing Record 29 of Set 7 | brookings
# Processing Record 30 of Set 7 | salekhard
# Processing Record 31 of Set 7 | rakops
# Processing Record 32 of Set 7 | hauterive
# Processing Record 33 of Set 7 | port mathurin
# Processing Record 34 of Set 7 | venev
# Processing Record 35 of Set 7 | juuka
# Processing Record 36 of Set 7 | hirna
# Processing Record 37 of Set 7 | kendari
# Processing Record 38 of Set 7 | santiago de cao
# Processing Record 39 of Set 7 | la mira
# Processing Record 40 of Set 7 | lakatoro
# Processing Record 41 of Set 7 | wau
# Processing Record 42 of Set 7 | concepcion
# Processing Record 43 of Set 7 | rimouski
# Processing Record 44 of Set 7 | mubi
# Processing Record 45 of Set 7 | nishishinminato
# Processing Record 46 of Set 7 | yuzhno-kurilsk
# Processing Record 47 of Set 7 | urangan
# Processing Record 48 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 49 of Set 7 | ventspils
# Processing Record 0 of Set 8 | kargasok
# Processing Record 1 of Set 8 | nacala
# Processing Record 2 of Set 8 | kayenta
# Processing Record 3 of Set 8 | debar
# Processing Record 4 of Set 8 | huarmey
# Processing Record 5 of Set 8 | celestun
# Processing Record 6 of Set 8 | labuan
# Processing Record 7 of Set 8 | nuku'alofa
# Processing Record 8 of Set 8 | kavieng
# Processing Record 9 of Set 8 | kudahuvadhoo
# Processing Record 10 of Set 8 | claveria
# Processing Record 11 of Set 8 | musay'id
# City not found. Skipping...
# Processing Record 12 of Set 8 | bahia de caraquez
# Processing Record 13 of Set 8 | chrysoupolis
# Processing Record 14 of Set 8 | bor
# Processing Record 15 of Set 8 | praia da vitoria
# Processing Record 16 of Set 8 | weno
# Processing Record 17 of Set 8 | la'ie
# Processing Record 18 of Set 8 | sibu
# Processing Record 19 of Set 8 | thayetmyo
# Processing Record 20 of Set 8 | toormina
# Processing Record 21 of Set 8 | kuybyshev
# Processing Record 22 of Set 8 | hobyo
# Processing Record 23 of Set 8 | archangelos
# Processing Record 24 of Set 8 | san cristobal cucho
# Processing Record 25 of Set 8 | warmbad
# Processing Record 26 of Set 8 | utrik
# Processing Record 27 of Set 8 | tenenkou
# Processing Record 28 of Set 8 | florence
# Processing Record 29 of Set 8 | quang ngai
# Processing Record 30 of Set 8 | lospalos
# Processing Record 31 of Set 8 | dolinsk
# Processing Record 32 of Set 8 | kinkala
# Processing Record 33 of Set 8 | letlhakane
# Processing Record 34 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 8 | dakhla
# Processing Record 36 of Set 8 | lensk
# Processing Record 37 of Set 8 | conception bay south
# Processing Record 38 of Set 8 | brezina
# Processing Record 39 of Set 8 | tidjikja
# Processing Record 40 of Set 8 | dudinka
# Processing Record 41 of Set 8 | shubarshi
# Processing Record 42 of Set 8 | la sarre
# Processing Record 43 of Set 8 | gobabis
# Processing Record 44 of Set 8 | ilha de mocambique
# Processing Record 45 of Set 8 | sorong
# Processing Record 46 of Set 8 | den burg
# Processing Record 47 of Set 8 | kuta
# Processing Record 48 of Set 8 | koryazhma
# Processing Record 49 of Set 8 | clarion
# Processing Record 0 of Set 9 | akobo
# Processing Record 1 of Set 9 | kita
# Processing Record 2 of Set 9 | gebeit
# Processing Record 3 of Set 9 | kani keli
# Processing Record 4 of Set 9 | tarawa
# Processing Record 5 of Set 9 | tadine
# Processing Record 6 of Set 9 | klyuchi
# Processing Record 7 of Set 9 | basco
# Processing Record 8 of Set 9 | bandarbeyla
# Processing Record 9 of Set 9 | yeppoon
# Processing Record 10 of Set 9 | santa ines
# Processing Record 11 of Set 9 | bonthe
# Processing Record 12 of Set 9 | penrith
# Processing Record 13 of Set 9 | myrhorod
# Processing Record 14 of Set 9 | cukai
# Processing Record 15 of Set 9 | una
# Processing Record 16 of Set 9 | punta del este
# Processing Record 17 of Set 9 | yarmouth
# Processing Record 18 of Set 9 | ilulissat
# Processing Record 19 of Set 9 | igunga
# Processing Record 20 of Set 9 | dubreka
# Processing Record 21 of Set 9 | severo-yeniseyskiy
# Processing Record 22 of Set 9 | nizhneangarsk
# Processing Record 23 of Set 9 | nishinoomote
# Processing Record 24 of Set 9 | ayame
# Processing Record 25 of Set 9 | ouellah
# City not found. Skipping...
# Processing Record 26 of Set 9 | la manga del mar menor
# Processing Record 27 of Set 9 | hefei
# Processing Record 28 of Set 9 | indiana
# Processing Record 29 of Set 9 | santa elena de uairen
# Processing Record 30 of Set 9 | nyrob
# Processing Record 31 of Set 9 | zaozersk
# Processing Record 32 of Set 9 | port macquarie
# Processing Record 33 of Set 9 | novodvinsk
# Processing Record 34 of Set 9 | mossel bay
# Processing Record 35 of Set 9 | phongsali
# Processing Record 36 of Set 9 | chrzanow
# Processing Record 37 of Set 9 | puerto baquerizo moreno
# Processing Record 38 of Set 9 | flin flon
# Processing Record 39 of Set 9 | alice springs
# Processing Record 40 of Set 9 | mancha real
# Processing Record 41 of Set 9 | kolokani
# Processing Record 42 of Set 9 | winejok
# City not found. Skipping...
# Processing Record 43 of Set 9 | san juan
# Processing Record 44 of Set 9 | punaauia
# Processing Record 45 of Set 9 | amalapuram
# Processing Record 46 of Set 9 | sarangani
# Processing Record 47 of Set 9 | bayan nur
# City not found. Skipping...
# Processing Record 48 of Set 9 | denbigh
# Processing Record 49 of Set 9 | kerikeri
# Processing Record 0 of Set 10 | la rioja
# Processing Record 1 of Set 10 | colonia
# Processing Record 2 of Set 10 | barclayville
# Processing Record 3 of Set 10 | bestobe
# Processing Record 4 of Set 10 | queenstown
# Processing Record 5 of Set 10 | palmerston north
# Processing Record 6 of Set 10 | marshall
# Processing Record 7 of Set 10 | gadzhiyevo
# Processing Record 8 of Set 10 | al 'alamayn
# City not found. Skipping...
# Processing Record 9 of Set 10 | bistrica ob sotli
# Processing Record 10 of Set 10 | caleta de carquin
# Processing Record 11 of Set 10 | trenggalek
# Processing Record 12 of Set 10 | keflavik
# Processing Record 13 of Set 10 | ulan bator
# Processing Record 14 of Set 10 | freeport
# Processing Record 15 of Set 10 | ayios konstandinos
# Processing Record 16 of Set 10 | portland
# Processing Record 17 of Set 10 | zhuanghe
# Processing Record 18 of Set 10 | klaksvik
# Processing Record 19 of Set 10 | kone
# Processing Record 20 of Set 10 | el bolson
# Processing Record 21 of Set 10 | finley
# Processing Record 22 of Set 10 | mamuju
# Processing Record 23 of Set 10 | dadonghai
# City not found. Skipping...
# Processing Record 24 of Set 10 | orhaneli
# Processing Record 25 of Set 10 | fort st. john
# Processing Record 26 of Set 10 | cockburn town
# Processing Record 27 of Set 10 | beteza
# City not found. Skipping...
# Processing Record 28 of Set 10 | faratsiho
# Processing Record 29 of Set 10 | seogwipo
# City not found. Skipping...
# Processing Record 30 of Set 10 | 'ain el melh
# Processing Record 31 of Set 10 | bathurst
# Processing Record 32 of Set 10 | sangkhla buri
# Processing Record 33 of Set 10 | amga
# Processing Record 34 of Set 10 | choma
# Processing Record 35 of Set 10 | forster
# Processing Record 36 of Set 10 | choyr
# Processing Record 37 of Set 10 | brisas de zicatela
# Processing Record 38 of Set 10 | taco pozo
# Processing Record 39 of Set 10 | acapulco de juarez
# Processing Record 40 of Set 10 | dondo
# Processing Record 41 of Set 10 | worland
# Processing Record 42 of Set 10 | cunha
# Processing Record 43 of Set 10 | qamdo
# Processing Record 44 of Set 10 | sao vicente
# Processing Record 45 of Set 10 | morant bay
# Processing Record 46 of Set 10 | horta
# Processing Record 47 of Set 10 | kailua-kona
# Processing Record 48 of Set 10 | itoman
# Processing Record 49 of Set 10 | majie
# Processing Record 0 of Set 11 | kenai
# Processing Record 1 of Set 11 | ust'-ilimsk
# Processing Record 2 of Set 11 | kalevala
# Processing Record 3 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 4 of Set 11 | olyokminsk
# Processing Record 5 of Set 11 | 'ohonua
# City not found. Skipping...
# Processing Record 6 of Set 11 | nogliki
# Processing Record 7 of Set 11 | garoua boulai
# Processing Record 8 of Set 11 | linqiong
# Processing Record 9 of Set 11 | porto recanati
# Processing Record 10 of Set 11 | sudzha
# Processing Record 11 of Set 11 | anibare
# City not found. Skipping...
# Processing Record 12 of Set 11 | chany
# Processing Record 13 of Set 11 | vygonichi
# Processing Record 14 of Set 11 | imbituba
# Processing Record 15 of Set 11 | malabar
# Processing Record 16 of Set 11 | ngala
# Processing Record 17 of Set 11 | vihari
# Processing Record 18 of Set 11 | maba
# Processing Record 19 of Set 11 | sebdou
# Processing Record 20 of Set 11 | shache
# Processing Record 21 of Set 11 | mont belvieu
# Processing Record 22 of Set 11 | turochak
# Processing Record 23 of Set 11 | sinop
# Processing Record 24 of Set 11 | cidreira
# Processing Record 25 of Set 11 | los chavez
# Processing Record 26 of Set 11 | ca mau
# Processing Record 27 of Set 11 | sylvan lake
# Processing Record 28 of Set 11 | san juan bautista
# Processing Record 29 of Set 11 | bengkulu
# Processing Record 30 of Set 11 | isla vista
# Processing Record 31 of Set 11 | itaguai
# Processing Record 32 of Set 11 | gaigeturi
# Processing Record 33 of Set 11 | tashtagol
# Processing Record 34 of Set 11 | bhamo
# Processing Record 35 of Set 11 | mar del plata
# Processing Record 36 of Set 11 | puerto leguizamo
# Processing Record 37 of Set 11 | ellsworth
# Processing Record 38 of Set 11 | raja
# Processing Record 39 of Set 11 | illizi
# Processing Record 40 of Set 11 | madara
# Processing Record 41 of Set 11 | faranah
# Processing Record 42 of Set 11 | laikit, laikit ii (dimembe)
# Processing Record 43 of Set 11 | paphos
# Processing Record 44 of Set 11 | kenitra
# Processing Record 45 of Set 11 | constitucion
# Processing Record 46 of Set 11 | bozkurt
# Processing Record 47 of Set 11 | galle
# Processing Record 48 of Set 11 | gazipasa
# Processing Record 49 of Set 11 | khandyga
# Processing Record 0 of Set 12 | coahuayana de hidalgo
# Processing Record 1 of Set 12 | shalqar
# Processing Record 2 of Set 12 | uvira
# Processing Record 3 of Set 12 | lima
# Processing Record 4 of Set 12 | alta
# Processing Record 5 of Set 12 | susuman
# Processing Record 6 of Set 12 | kerewan
# Processing Record 7 of Set 12 | palmer
# Processing Record 8 of Set 12 | huehuetenango
# Processing Record 9 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 12 | mutuali
# Processing Record 11 of Set 12 | vilyuchinsk
# Processing Record 12 of Set 12 | chicomuselo
# Processing Record 13 of Set 12 | okhotsk
# Processing Record 14 of Set 12 | santana
# Processing Record 15 of Set 12 | muncar
# Processing Record 16 of Set 12 | gunjur
# Processing Record 17 of Set 12 | sidhi
# Processing Record 18 of Set 12 | kingston
# Processing Record 19 of Set 12 | le morne-rouge
# Processing Record 20 of Set 12 | inari
# Processing Record 21 of Set 12 | tchintabaraden
# Processing Record 22 of Set 12 | bridgewater
# Processing Record 23 of Set 12 | esquina
# Processing Record 24 of Set 12 | ankang
# Processing Record 25 of Set 12 | baracoa
# Processing Record 26 of Set 12 | bahia blanca
# Processing Record 27 of Set 12 | kemijarvi
# Processing Record 28 of Set 12 | novyy turtkul'
# Processing Record 29 of Set 12 | tulucesti
# Processing Record 30 of Set 12 | jayapura
# Processing Record 31 of Set 12 | mersa matruh
# Processing Record 32 of Set 12 | las heras
# Processing Record 33 of Set 12 | suileng
# Processing Record 34 of Set 12 | al khums
# Processing Record 35 of Set 12 | laguna
# Processing Record 36 of Set 12 | zakamensk
# Processing Record 37 of Set 12 | san antonio de pale
# Processing Record 38 of Set 12 | sault ste. marie
# Processing Record 39 of Set 12 | tanrake village
# City not found. Skipping...
# Processing Record 40 of Set 12 | rayleigh
# Processing Record 41 of Set 12 | devinuwara
# City not found. Skipping...
# Processing Record 42 of Set 12 | damavand
# Processing Record 43 of Set 12 | airway heights
# Processing Record 44 of Set 12 | kosciuszko national park
# City not found. Skipping...
# Processing Record 45 of Set 12 | coquimbo
# Processing Record 46 of Set 12 | puerto deseado
# Processing Record 47 of Set 12 | tabatinga
# Processing Record 48 of Set 12 | senador jose porfirio
# Processing Record 49 of Set 12 | garissa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[["City", 
                             "Lat", 
                             "Lng", 
                             "Max Temp", 
                             "Humidity", 
                             "Cloudiness", 
                             "Wind Speed", 
                             "Country", 
                             "Date"]]

# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167     43.48        89         100
# 1         hammerfest  70.6634   23.6821     52.25        82         100
# 2            talnakh  69.4865   88.3972     69.21        49           0
# 3         siwa oasis  29.2041   25.5195     86.41        55           0
# 4           kayangel   8.0823  134.7173     79.81        86         100
#
#    Wind Speed Country        Date
# 0       37.63      TF  1691370871
# 1        0.00      NO  1691370893
# 2        5.97      RU  1691370893
# 3       10.07      EG  1691370894
# 4       18.68      PW  1691370894

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167     43.48        89         100
# 1               hammerfest  70.6634   23.6821     52.25        82         100
# 2                  talnakh  69.4865   88.3972     69.21        49           0
# 3               siwa oasis  29.2041   25.5195     86.41        55           0
# 4                 kayangel   8.0823  134.7173     79.81        86         100
#
#          Wind Speed Country        Date
# City_ID
# 0             37.63      TF  1691370871
# 1              0.00      NO  1691370893
# 2              5.97      RU  1691370893
# 3             10.07      EG  1691370894
# 4             18.68      PW  1691370894

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolor="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (2023-8-6)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolor="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2023-8-6)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolor="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2023-8-6)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolor="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2023-8-6)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg_plot(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    print(f"The r-value is: {rvalue}")
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")

def annotation(line_eq, x, y):
    plt.annotate(line_eq, (x, y), fontsize=15, color="red")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        hammerfest  70.6634   23.6821     52.25        82         100
# 2           talnakh  69.4865   88.3972     69.21        49           0
# 3        siwa oasis  29.2041   25.5195     86.41        55           0
# 4          kayangel   8.0823  134.7173     79.81        86         100
# 6             revda  56.8010   59.9303     58.80        99          27
#
#          Wind Speed Country        Date
# City_ID
# 1              0.00      NO  1691370893
# 2              5.97      RU  1691370893
# 3             10.07      EG  1691370894
# 4             18.68      PW  1691370894
# 6              3.62      RU  1691370894

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167     43.48        89         100
# 5                sarmiento -45.5882  -69.0700     39.43        65           2
# 8                 waitangi -43.9535 -176.5597     51.82        77          90
# 12          margaret river -33.9500  115.0667     60.01        78          16
# 15               san borja -14.8167  -66.8500     78.55        51           0
#
#          Wind Speed Country        Date
# City_ID
# 0             37.63      TF  1691370871
# 5              5.53      AR  1691370894
# 8              1.01      NZ  1691370894
# 12            10.83      AU  1691370610
# 15             2.77      BO  1691370895

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plotting = lin_reg_plot(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
annotation(plotting, 10, 40)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.show()
# Out:
# The r-value is: -0.6261507314192517

# %%
# Linear regression on Southern Hemisphere
plotting = lin_reg_plot(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
annotation(plotting, -20, 30)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.show()
# Out:
# The r-value is: 0.8123604179194173

# %% [markdown]
# **Discussion about the linear relationship: For the northern hemisphere, there is a fairly strong negative correlation between latitude and max temp. For the southern hemisphere, there is a strong positive correlation between latitude and max temp.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plotting = lin_reg_plot(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
annotation(plotting, 40, 10)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.show()
# Out:
# The r-value is: -0.12544900677616938

# %%
# Southern Hemisphere
plotting = lin_reg_plot(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
annotation(plotting, -50, 20)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.show()
# Out:
# The r-value is: -0.05159734787525157

# %% [markdown]
# **Discussion about the linear relationship: For both the northern and southern hemispheres, there is a very weak negative correlation between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plotting = lin_reg_plot(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
annotation(plotting, 40, 15)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()
# Out:
# The r-value is: -0.07358856280730416

# %%
# Southern Hemisphere
plotting = lin_reg_plot(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
annotation(plotting, -50, 20)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()
# Out:
# The r-value is: 0.12168332894188161

# %% [markdown]
# **Discussion about the linear relationship: For the northern hemisphere there is a very week negative correlation, and for the southern hemisphere there is a very weak positive correlation between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plotting = lin_reg_plot(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
annotation(plotting, 10, 13)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()
# Out:
# The r-value is: -0.16704580753551987

# %%
# Southern Hemisphere
plotting = lin_reg_plot(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
annotation(plotting, -50, 12)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()
# Out:
# The r-value is: -0.019399353159146777

# %% [markdown]
# **Discussion about the linear relationship: For both the northern and southern hemispheres, there is a weak negative correlation between latitude and wind speed.
